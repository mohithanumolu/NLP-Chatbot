# %% [markdown]
# <a href="https://colab.research.google.com/github/mohithanumolu/NLP-Chatbot/blob/main/NLP%E2%80%91Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intents = {
    "greeting": ["hello", "hi", "hey"],
    "goodbye": ["bye", "see you", "goodnight"],
    "thanks": ["thank you", "thanks"],
    "info": ["what is your name", "who are you"]
}

responses = {
    "greeting": "Hello! How can I help you today?",
    "goodbye": "Goodbye! Have a great day.",
    "thanks": "You're welcome!",
    "info": "I am a simple chatbot built in Python."
}

# %%
import nltk
from nltk.tokenize import word_tokenize


nltk.download('punkt_tab')

def get_intent(user_input):
    tokens = word_tokenize(user_input.lower())
    for intent, keywords in intents.items():
        for word in tokens:
            if word in keywords:
                return intent
    return None

while True:
    user_input = input("You: ")
    if user_input.lower() in ["quit", "exit"]:
        print("Chatbot: Goodbye!")
        break
    intent = get_intent(user_input)
    if intent:
        print("Chatbot:", responses[intent])
    else:
        print("Chatbot: Sorry, I didn't understand that.")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# You: hi
# Chatbot: Hello! How can I help you today?
# You: thank you
# Chatbot: Sorry, I didn't understand that.
# You: thanks
# Chatbot: You're welcome!
# You: bye
# Chatbot: Goodbye! Have a great day.
